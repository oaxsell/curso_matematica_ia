# %% [markdown]
# # O que vamos aprender?

# %% [markdown]
# - O que é Numpy
# - Manipular arrays (ndarray)
# - Indexação
# - Operações vetorizadas
# - Algebra Linear e Estatística (Probabilidade e Est. Bayesiana)
# - Performance: NumPy vs. Listas Nativas Python
# - Boas práticas e solução do projeto

# %%
print("Thomas Bayes vai revirar no túmulo!")
# Out:
# Thomas Bayes vai revirar no túmulo!

# %% [markdown]
# #### Por que o NumPy é o coração da ciencia de dados em Python?

# %% [markdown]
# - Pandas
# - Sciki-learn
# - TensorFlow (redes neurais)
# - MatplotLib

# %%
import numpy as np

# %% [markdown]
# - Lista do Python x Array do NumPy

# %% [markdown]
# - Vetor ou Matriz Unidimensional

# %% [markdown]
# ### Porque o NumPy Array e mais rapido que uma lista Python

# %% [markdown]
# - Lista e a sacola do supermercado
# - Array do NumPy - caixa de ovos
# - C e Fortran: 50x
# - O NymPy permite a vetorizacao

# %% [markdown]
# # Aula 1 - Download de DataSets

# %% [markdown]
# - Iris
# - Petrobras (acoes)
# - Macas

# %%
import numpy as np

# %%
np.__version__
# Out:
# '2.3.5'

# %%
np.loadtxt('datasets/iris_lucio.csv', delimiter=',',skiprows=1, usecols=(0,1,2,3))
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %% [markdown]
# # Nossos DataSets

# %% [markdown]
# #### Iris (Nosso Hello World! Data Science)

# %% [markdown]
# - Classíco - DC e ML
# - Edgar Anderson , Ronald A. Fisher em 1936
# - 150 amostras - três especies (setosa,versicolor,virginica)
# - comprimento e a largura (sépalas e pétalas)

# %% [markdown]
# #### Petrobras.xlsx

# %% [markdown]
# - Mercado Financeiro- o retorno financeiro
# - Rentabilidade de um ativo financeiro em relação ao outro
# - Volatividade de um ativo em relação ao outro
# - 5 minutos planilha é atualizada

# %% [markdown]
# ret = preco(i) - preco(i-1) / preco (i-1)

# %% [markdown]
# #### Apples.csv

# %% [markdown]
# - Cada linha é uma cidade da Russia
# - Cada coluna uma data (mes-ano) - 12 anos.

# %% [markdown]
# #### Bibliotecas

# %% [markdown]
# - NumPy
# - SciPy
# - MatplotLib

# %% [markdown]
# EDA Iris Com NumPy

# %%
data_iris = np.loadtxt('datasets/iris_Lucio.csv', delimiter=',',skiprows=1, usecols=(0,1,2,3))

# %%
# cinco primeiras linhas
data_iris[:5]
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2]])

# %%
print(data_iris[:5])
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]]

# %%
data_iris.shape
# Out:
# (150, 4)

# %%
data_iris.dtype
# Out:
# dtype('float64')

# %%
# somar a primeira linha
print(f"soma da primeira linha {data_iris[0].sum()}")
# Out:
# soma da primeira linha 10.2

# %%
# somar a primeira coluna
print(f"soma da primeira coluna {data_iris[:,0].sum()}")
# Out:
# soma da primeira coluna 876.5

# %%
print(f"sepal_lenght {data_iris[:,0].mean()}")
# Out:
# sepal_lenght 5.843333333333334

# %% [markdown]
# - std() - desvio  padrao
# - max()
# - min()
# - sum()
# - prod()
# - var()

# %% [markdown]
# ### Criando um Histograma

# %%
! pip install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.10.7-cp311-cp311-win_amd64.whl (8.1 MB)
# ...
#   Using cached contourpy-1.3.3-cp311-cp311-win_amd64.whl (225 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#                                               0.0/2.3 MB ? eta -:--:--
#      ---                                      0.2/2.3 MB 4.6 MB/s eta 0:00:01
#      -----------------                        1.0/2.3 MB 12.9 MB/s eta 0:00:01
#      ---------------------------------------  2.3/2.3 MB 18.5 MB/s eta 0:00:01
#      ---------------------------------------- 2.3/2.3 MB 16.4 MB/s eta 0:00:00
# ...
#   Using cached kiwisolver-1.4.9-cp311-cp311-win_amd64.whl (73 kB)
# ...
#   Using cached numpy-2.3.5-cp311-cp311-win_amd64.whl (13.1 MB)
# ...
#   Using cached pillow-12.0.0-cp311-cp311-win_amd64.whl (7.0 MB)
# ...
#   Using cached pyparsing-3.2.5-py3-none-any.whl (113 kB)
# ...
# [notice] A new release of pip is available: 23.1.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

# %%
# 10 barrinhas
plt.hist(data_iris[:,0], bins=10)
plt.title("Histograma do Sepal Length")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Frequencia")
# Out:
# Text(0, 0.5, 'Frequencia')

# %%
# Histograma sepal_width
plt.hist(data_iris[:,0], bins=10)
plt.title("Histograma do Sepal Width")
plt.xlabel("Sepal Width (cm)")
plt.ylabel("Frequencia")
# Out:
# Text(0, 0.5, 'Frequencia')

# %%
# Histograma petal_length
plt.hist(data_iris[:,0], bins=10)
plt.title("Histograma do Petal Length")
plt.xlabel("Petal Length (cm)")
plt.ylabel("Frequencia")
# Out:
# Text(0, 0.5, 'Frequencia')

# %%
# Histograma petal_width
plt.hist(data_iris[:,0], bins=10)
plt.title("Histograma do Petal Width")
plt.xlabel("Petal Width (cm)")
plt.ylabel("Frequencia")
# Out:
# Text(0, 0.5, 'Frequencia')

# %%
# Histograma petal_width
plt.hist(data_iris[:,0], bins=10)
plt.title("Histograma dp Petal Width")
plt.xlabel("Petal Width (cm)")
plt.ylabel("Frequencia")
